# %%
# !pip install google-play-scraper

# %%
# Import library
from google_play_scraper import reviews_all, Sort
import csv
import pandas as pd

# %%
from google_play_scraper import app, reviews_all, Sort

# Scrapping Data Ulasan Google Play
scrapreview = reviews_all(
    'com.mobile.legends', # ID aplikasi
    lang='en', # Bahasa ulasan
    country='id', # Negara
    sort=Sort.MOST_RELEVANT, # Urutan ulasan
    count=11000 # Jumlah maksimal ulasan
)

# %%
# Simpan dalam CSV
with open('review_game_mobile_legends.csv', mode='w', newline='', encoding='utf-8') as file :
  writer = csv.writer(file)
  writer.writerow(['review'])
  for review in scrapreview :
    writer.writerow([review['content']])

# %%
df =pd.read_csv('review_game_mobile_legends.csv')
df
# Out:
#                                                   review
# 0      Moonton has very poor matchmaking. Sometimes s...
# 1      Was a great game, simple to play, easy to unde...
# 2      Dear admin, I want to convey the problem I am ...
# 3      Dear Moonton, if you make a game that's correc...
# 4      Mobile Legends has a lot of potential, but it ...
# ...                                                  ...
# 71995  English is not my first language so bare with ...
# 71996  I always play this game for almost everyday. T...
# 71997  The keeps crashing even though im only in the ...
# 71998  It's still a great game<< old review, 2019 rev...
# 71999  Poor system performance. I never like the matc...
#
# [72000 rows x 1 columns]
